# %%
import numpy as np
import matplotlib.pyplot as plt
import pyabf
import os

def plot_single_trace(abf_path):
    
    # Load ABF file
    abf = pyabf.ABF(abf_path)
    
    # Get data
    time = abf.sweepX
    current = abf.sweepY
    
    ##EB6F6F color for NA
    # Create plot
    plt.figure(figsize=(12, 6))
    plt.plot(time, current, '#EB6F6F', linewidth=1)
    plt.ylim(-100,0)
    plt.xlim(39,41.5)
    #plt.title(f'sEPSC Recording - {os.path.basename(abf_path)}')
    
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add scale bar
    x_start = 41
    y_start = -90
    x_bar = 0.1   # seconds
    y_bar = 10  # pA

    # Horizontal scale bar
    plt.plot([x_start, x_start + x_bar], [y_start, y_start], color='k', lw=2)
    # Vertical scale bar
    plt.plot([x_start + x_bar, x_start + x_bar], [y_start, y_start + y_bar], color='k', lw=2)

    # Add text labels
    plt.text(x_start + x_bar / 2, y_start - 3, '0.1 s', ha='center', va='top', fontsize=10)
    plt.text(x_start + x_bar + 0.03, y_start + y_bar / 2, '10 pA', ha='left', va='center', fontsize=10)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()

# Usage
abf_path ="C:\\Users\\rbondare\\ephys\\results\\Example Traces\\\sIPSC\\2025_07_29_0014 NA.abf"
save_path = abf_path.replace('.abf', '.pdf')


plot_single_trace(abf_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyabf
import os

def plot_single_trace(abf_path):
    
    # Load ABF file
    abf = pyabf.ABF(abf_path)
    
    # Get data
    time = abf.sweepX
    current = abf.sweepY
    
    ##EB6F6F color for NA
    # Create plot
    plt.figure(figsize=(12, 6))
    plt.plot(time, current,'#EB6F6F', linewidth=1)
    plt.ylim(-50, -200)
    plt.xlim(3.5,5)
    plt.title(f'sEPSC Recording - {os.path.basename(abf_path)}')
    
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add scale bar
    x_start = 4.5
    y_start = -80
    x_bar = 0.1   # seconds
    y_bar = 10  # pA

    # Horizontal scale bar
    plt.plot([x_start, x_start + x_bar], [y_start, y_start], color='k', lw=2)
    # Vertical scale bar
    plt.plot([x_start + x_bar, x_start + x_bar], [y_start, y_start + y_bar], color='k', lw=2)

    # Add text labels
    plt.text(x_start + x_bar / 2, y_start - 3, '0.1 s', ha='center', va='top', fontsize=10)
    plt.text(x_start + x_bar + 0.03, y_start + y_bar / 2, '10 pA', ha='left', va='center', fontsize=10)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()

# Usage
abf_path ="C:\\Users\\rbondare\\ephys\\results\\Example Traces\\sEPSC\\2025_07_30_0007 NA.abf"
save_path = abf_path.replace('.abf', '.pdf')


plot_single_trace(abf_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyabf
import os

def plot_single_trace(abf_path):
    
    # Load ABF file
    abf = pyabf.ABF(abf_path)
    
    # Get data
    time = abf.sweepX
    current = abf.sweepY
    
    ##EB6F6F color for NA
    # Create plot
    plt.figure(figsize=(12, 6))
    plt.plot(time, current, 'gray', linewidth=1)
    plt.ylim(-50, -200)
    plt.xlim(12,14.5)
    plt.title(f'sEPSC Recording - {os.path.basename(abf_path)}')
    
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_visible(False)

    # # Add scale bar
    # x_start = 7.5
    # y_start = -90
    # x_bar = 1   # seconds
    # y_bar = 10  # pA

    # # Horizontal scale bar
    # plt.plot([x_start, x_start + x_bar], [y_start, y_start], color='k', lw=2)
    # # Vertical scale bar
    # plt.plot([x_start + x_bar, x_start + x_bar], [y_start, y_start + y_bar], color='k', lw=2)

    # # Add text labels
    # plt.text(x_start + x_bar / 2, y_start - 3, '1 s', ha='center', va='top', fontsize=10)
    # plt.text(x_start + x_bar + 0.03, y_start + y_bar / 2, '10 pA', ha='left', va='center', fontsize=10)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()

# Usage
abf_path ="C:\\Users\\rbondare\\ephys\\results\\Example Traces\\sEPSC\\2025_07_30_0006 Baseline.abf"
save_path = abf_path.replace('.abf', '.pdf')


plot_single_trace(abf_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyabf
import os

def plot_single_trace(abf_path):
    
    # Load ABF file
    abf = pyabf.ABF(abf_path)
    
    # Get data
    time = abf.sweepX
    current = abf.sweepY
    
    ##EB6F6F color for NA
    # Create plot
    plt.figure(figsize=(12, 6))
    plt.plot(time, current, 'gray', linewidth=1)
    plt.ylim(-70, -140)
    plt.xlim(3,5)
    plt.title(f'sEPSC Recording - {os.path.basename(abf_path)}')
    
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_visible(False)

    # # Add scale bar
    # x_start = 7.5
    # y_start = -90
    # x_bar = 1   # seconds
    # y_bar = 10  # pA

    # # Horizontal scale bar
    # plt.plot([x_start, x_start + x_bar], [y_start, y_start], color='k', lw=2)
    # # Vertical scale bar
    # plt.plot([x_start + x_bar, x_start + x_bar], [y_start, y_start + y_bar], color='k', lw=2)

    # # Add text labels
    # plt.text(x_start + x_bar / 2, y_start - 3, '1 s', ha='center', va='top', fontsize=10)
    # plt.text(x_start + x_bar + 0.03, y_start + y_bar / 2, '10 pA', ha='left', va='center', fontsize=10)
    # # plt.tight_layout()
    # # plt.show()

# Usage
abf_path ="C:\\Users\\rbondare\\ephys\\results\\Example Traces\\sEPSC\\2025_07_30_0007 NA.abf"
save_path = abf_path.replace('.abf', '.pdf')


plot_single_trace(abf_path)
#plt.savefig(save_path, dpi=300)
