# %% [markdown]
# Script to analyse and plot RESTING MEMBRANE POTENTIAL (RMP)

# %%
import pyabf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns  
from statsmodels.stats.anova import AnovaRM
import pingouin as pg
sns.set_context('poster')

# %%
"""

Script to extract resting membrane potential (RMP) from ABF files and add it to an existing Excel file (file with all the results)
Use this to recalculate the RMP values for all cells in the database.
Otherwise plot existing 

"""
def extract_rmp_from_abf(abf_file):
    """
    Extract resting membrane potential from an ABF file by averaging 
    the first 100ms of each sweep, then averaging across all sweeps.
    """
    abf = pyabf.ABF(abf_file)
    sweep_rmp_values = []
    sweep_indices = abf.sweepList[-10:] if len(abf.sweepList) > 10 else abf.sweepList

    for sweep in sweep_indices:
        abf.setSweep(sweep)  # Set the current sweep
        first_100ms = abf.sweepY[:int(0.1 * abf.dataRate)]  # First 100 ms
        sweep_rmp_values.append(np.mean(first_100ms))  # Calculate mean for the sweep
    
    # Average across all sweeps
    rmp = np.mean(sweep_rmp_values)
    return rmp

def _load_results_table(csv_file_path):
    # Support both old format (header at row 2) and rewritten format (header at row 1).
    for header_row in (0, 1):
        df = pd.read_excel(csv_file_path, header=header_row)
        df.columns = df.columns.astype(str).str.strip()
        if 'filepath' in df.columns:
            return df
    raise KeyError("Could not find 'filepath' column with header=0 or header=1")

def add_rmp_to_excel(csv_file_path):
    """
    Add RMP column to existing Excel file by processing each ABF file.
    """
    results_df = _load_results_table(csv_file_path)

    # Fast precheck: fail early if mount/path is unavailable
    path_exists = results_df['filepath'].astype(str).map(os.path.exists)
    n_existing = int(path_exists.sum())
    n_total = len(results_df)
    print(f"Path check: {n_existing}/{n_total} ABF files found")
    if n_existing == 0:
        first_example = results_df['filepath'].dropna().astype(str).head(1).tolist()
        example_msg = first_example[0] if first_example else 'No filepath values found'
        raise RuntimeError(
            "No ABF files were found at the listed paths. "
            f"Please verify the volume is mounted. Example missing path: {example_msg}"
        )
    
    # Add new column for RMP if it doesn't exist
    if 'RMP' not in results_df.columns:
        results_df['RMP'] = None
    
    # Process each row to calculate RMP
    for i, row in results_df.iterrows():
        if pd.notna(row['filepath']) and os.path.exists(row['filepath']):
            print(f"Processing file {i+1}/{len(results_df)}: {row['filepath']}")
            
            try:
                rmp = extract_rmp_from_abf(abf_file=row['filepath'])
                # Update the specific row
                results_df.at[i, 'RMP'] = rmp
            except Exception as e:
                print(f"Error processing {row['filepath']}: {e}")
                results_df.at[i, 'RMP'] = None
        else:
            # Handle missing files
            results_df.at[i, 'RMP'] = None
            print(f"File not found: {row.get('filepath', 'N/A')}")

    # Save back to the same file with standard header row
    results_df.to_excel(csv_file_path, index=False)
    print("Updated Excel file saved with new 'RMP' column")
    
    # Filter and display summary
    if 'comment' in results_df.columns:
        filtered_df = results_df[results_df['comment'].astype(str).str.strip().str.lower() != "exclude"]
        print(f"Number of cells after filtering: {len(filtered_df)}")

# %%
results_df = _load_results_table("/Users/rbondare/ephys/metadata/all_peak_results_final.xlsx")
print(results_df.columns.tolist())
master_file = "/Users/rbondare/ephys/metadata/all_peak_results_final.xlsx"
add_rmp_to_excel(master_file)
# Out:
# ['filepath', 'filename', 'condition', 'genotype', 'ID', 'total_sweeps', 'normalized_first_peak', 'normalized_all_peaks', 'comment', 'RMP']
# Path check: 92/92 ABF files found
# Processing file 1/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0002.abf
# Processing file 2/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0003.abf
# Processing file 3/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0004.abf
# Processing file 4/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0007.abf
# Processing file 5/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0008.abf
# Processing file 6/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0009.abf
# Processing file 7/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0012.abf
# Processing file 8/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0013.abf
# Processing file 9/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0014.abf
# Processing file 10/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0004.abf
# Processing file 11/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0007.abf
# Processing file 12/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0008.abf
# Processing file 13/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0012.abf
# Processing file 14/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0013.abf
# Processing file 15/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0014.abf
# Processing file 16/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0018.abf
# Processing file 17/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0019.abf
# Processing file 18/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0020.abf
# Processing file 19/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0025.abf
# Processing file 20/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0026.abf
# Processing file 21/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0027.abf
# Processing file 22/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0031.abf
# Processing file 23/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0032.abf
# Processing file 24/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0033.abf
# Processing file 25/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0039.abf
# Processing file 26/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0040.abf
# Processing file 27/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0041.abf
# Processing file 28/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0020.abf
# Processing file 29/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0021.abf
# Processing file 30/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0022.abf
# Processing file 31/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0025.abf
# Processing file 32/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0026.abf
# Processing file 33/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0027.abf
# Processing file 34/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0031.abf
# Processing file 35/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0032.abf
# Processing file 36/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0033.abf
# Processing file 37/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0002.abf
# Processing file 38/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0003.abf
# Processing file 39/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0004.abf
# Processing file 40/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0007.abf
# Processing file 41/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0008.abf
# Processing file 42/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0009.abf
# Processing file 43/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0012.abf
# Processing file 44/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0013.abf
# Processing file 45/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0014.abf
# Processing file 46/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/13.05.2025 M7/2025_05_13_0031.abf
# Processing file 47/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/13.05.2025 M7/2025_05_13_0032.abf
# Processing file 48/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/13.05.2025 M7/2025_05_13_0033.abf
# Processing file 49/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M8/2025_05_15_0002.abf
# Processing file 50/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M8/2025_05_15_0003.abf
# Processing file 51/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M8/2025_05_15_0004.abf
# Processing file 52/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0026.abf
# Processing file 53/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0027.abf
# Processing file 54/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0028.abf
# Processing file 55/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0033.abf
# Processing file 56/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0034.abf
# Processing file 57/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0035.abf
# Processing file 58/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0001.abf
# Processing file 59/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0002.abf
# Processing file 60/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0003.abf
# Processing file 61/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0006.abf
# Processing file 62/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0007.abf
# Processing file 63/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0008.abf
# Processing file 64/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0011.abf
# Processing file 65/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0012.abf
# Processing file 66/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0013.abf
# Processing file 67/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0017.abf
# Processing file 68/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0018.abf
# Processing file 69/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0019.abf
# Processing file 70/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0022.abf
# Processing file 71/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0023.abf
# Processing file 72/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0024.abf
# Processing file 73/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0028.abf
# Processing file 74/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0029.abf
# Processing file 75/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0030.abf
# Processing file 76/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0002.abf
# Processing file 77/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0003.abf
# Processing file 78/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0004.abf
# Processing file 79/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0008.abf
# Processing file 80/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0009.abf
# Processing file 81/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0010.abf
# Processing file 82/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0014.abf
# Processing file 83/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0015.abf
# Processing file 84/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0016.abf
# Processing file 85/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0017.abf
# Processing file 86/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0018.abf
# Processing file 87/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0015.abf
# Processing file 88/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0016.abf
# Processing file 89/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0017.abf
# Processing file 90/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0018.abf
# Processing file 91/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0022.abf
# Processing file 92/92: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0023.abf
# Updated Excel file saved with new 'RMP' column
# Number of cells after filtering: 81

# %%
import seaborn as sns
from ephys_functions import add_significance

def plot_rmp(results_df):
    """
    Plot resting membrane potential (RMP) by condition for each genotype.
    """
    genotypes = results_df['genotype'].unique()
    conditions = ['baseline', 'Noradrenaline', 'wash']
    colors = ['lightgrey', 'lightcoral', 'lightblue']
    
    fig, axes = plt.subplots(1, len(genotypes), figsize=(8, 5), sharey=True)
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        group = results_df[results_df['genotype'] == genotype]

        if group.empty:
            continue
        
        # Create jittered x positions
        jitter_amount = 0.1
        np.random.seed(42)
        
        # Plot each cell as a line across conditions
        for _, row in group.iterrows():
            y = [row[cond] for cond in conditions if pd.notna(row[cond])]
            
            # Only plot if we have data for all conditions
            if len(y) == len(conditions):
                x_jittered = [i + np.random.uniform(-jitter_amount, jitter_amount) for i in range(len(conditions))]
                
                ax.plot(x_jittered, y, color='lightgray', alpha=0.8, linewidth=1)
                ax.scatter(x_jittered, y, color=colors, s=60, zorder=3, edgecolors='black', linewidths=0.7)
        
        # Plot means
        for i, cond in enumerate(conditions):
            y_vals = group[cond].dropna().values
            if len(y_vals) > 0:
                ax.hlines(np.mean(y_vals), i - 0.15, i + 0.15, color='black', linewidth=5)
        
        ax.set_xticks(range(len(conditions)))
        ax.set_xticklabels(['baseline', 'NA', 'wash'], rotation=45)
        ax.set_title(f"{genotype}", fontsize=12)
        ax.set_xlim(-0.5, len(conditions) - 0.5)
    
    # Set y-label only on the leftmost plot - FIXED LABEL
    axes[0].set_ylabel("Resting Membrane Potential (mV)")
    plt.tight_layout()
    plt.show()


def add_significance(ax, pairs, pvalues, y_offset_from_top=0.02, h=0.03, fontsize=12):
    """
    Draw significance bars and stars at the top of the figure.
    """
    # Increase y_offset_from_top to make bars/stars higher
    y_offset_from_top = -0.06  
    ymin, ymax = ax.get_ylim()
    plot_height = ymax - ymin
    
    # Start from the top and work downward
    for i, ((x1, x2), pval) in enumerate(zip(pairs, pvalues)):
        if pval < 0.001:
            stars = '***'
        elif pval < 0.01:
            stars = '**'
        elif pval < 0.05:
            stars = '*'
        else:
            stars = 'n.s.'

        # Calculate y position from top (working downward)
        y = ymax - (y_offset_from_top + i * h) * plot_height
        bar_height = h * plot_height * 0.5  # Height of the significance bar
        
        # Draw the significance bar
        ax.plot([x1, x1, x2, x2], [y, y - bar_height, y - bar_height, y],
                lw=1.5, c='k')
        
        # Add the significance text
        ax.text((x1+x2)/2, y - bar_height * 0.5, stars,
                ha='center', va='top', fontsize=fontsize)


def plot_rmp_boxplot_grouped(pivot):
    """
    Plot resting membrane potential (RMP) in a single axis with both genotypes.
    Each genotype shows 3 conditions grouped together for easy comparison.
    Includes repeated-measures ANOVA and post-hoc statistical analysis.
    """
    genotypes = pivot['genotype'].unique()
    conditions = ['baseline', 'Noradrenaline', 'wash']
    colors_bar = ["#A2A0A0", "#EB6F6F", "#89CFF0"]  # Colors for the mean lines and points

    genotype_posthoc = {}
    genotype_positions = {}

    # ---------- Run statistical analysis for each genotype ----------
    for genotype in genotypes:
        group = pivot[pivot['genotype'] == genotype]
        if group.empty:
            continue

        # Melt to long format for ANOVA
        long_df = group.melt(
            id_vars=['ID', 'genotype'],
            value_vars=conditions,
            var_name='condition',
            value_name='RMP'
        )

        try:
            aov = AnovaRM(
                data=long_df,
                depvar='RMP',
                subject='ID',
                within=['condition']
            ).fit()

            # Post-hoc pairwise tests with Bonferroni correction
            posthoc = pg.pairwise_tests(
                dv='RMP',
                within='condition',
                subject='ID',
                data=long_df,
                padjust='bonf'
            )
            if 'p_corr' in posthoc.columns:
                p_col = 'p_corr'
            elif 'p-corr' in posthoc.columns:
                p_col = 'p-corr'
            elif 'p_unc' in posthoc.columns:
                p_col = 'p_unc'
            else:
                p_col = 'p-unc'

            pairs = []
            pvals = []
            for _, row in posthoc.iterrows():
                A, B, pval = row['A'], row['B'], row[p_col]
                pairs.append((A, B))
                pvals.append(float(pval))
                print(f"    {A} vs {B}: p = {pval:.4f}")
            genotype_posthoc[genotype] = (pairs, pvals)
        except Exception as e:
            print(f"Error during ANOVA or post-hoc tests for genotype {genotype}: {e}")
            posthoc = None

    # ---------- Create the plot ----------
    plt.figure(figsize=(10, 10))
    ax = plt.gca()

    # Calculate x positions - group conditions for each genotype
    n_conditions = len(conditions)
    condition_width = 0.25  # Width between conditions within a group
    genotype_spacing = 1.5  # Spacing between genotype groups
    
    jitter_amount = 0.08
    np.random.seed(42)

    for g_idx, genotype in enumerate(genotypes):
        group = pivot[pivot['genotype'] == genotype]
        
        if group.empty:
            continue

        # Calculate x positions for this genotype's conditions
        genotype_center = g_idx * genotype_spacing
        condition_positions = [genotype_center + (i - 1) * condition_width for i in range(n_conditions)]
        genotype_positions[genotype] = condition_positions
        
        # Plot individual points only 
        for _, row in group.iterrows():
            for i, cond in enumerate(conditions):
                if pd.notna(row[cond]):
                    x_jittered = condition_positions[i] + np.random.uniform(-jitter_amount, jitter_amount)
                    ax.scatter(x_jittered, row[cond], color=colors_bar[i], alpha=0.6, s=60, zorder=2,
                              edgecolors='black', linewidths=0.1)

        # Draw thick horizontal median lines for each condition
        for i, cond in enumerate(conditions):
            y_vals = group[cond].dropna().values
            if len(y_vals) > 0:
                x_pos = condition_positions[i]
                ax.hlines(np.median(y_vals), x_pos - 0.1, x_pos + 0.1,
                         color=colors_bar[i], linewidth=4.5, zorder=3)

    # Add significance brackets for each genotype
    for genotype in genotypes:
        if genotype in genotype_posthoc and genotype in genotype_positions:
            pairs, pvals = genotype_posthoc[genotype]
            mapping = {cond: genotype_positions[genotype][i] for i, cond in enumerate(conditions)}
            mapped_pairs = [(mapping[a], mapping[b]) for a, b in pairs if a in mapping and b in mapping]
            if mapped_pairs and pvals:
                add_significance(ax, mapped_pairs, pvals)

    # Leave headroom for the brackets
    ax.set_ylim(-85, -28)

    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Set x-axis - just show genotype names
    genotype_centers = []
    for g_idx, genotype in enumerate(genotypes):
        genotype_center = g_idx * genotype_spacing
        genotype_centers.append(genotype_center)
    
    ax.set_xticks(genotype_centers)
    ax.set_xticklabels(['Gad67$^+$', 'Ntsr1$^+$'])
    ax.set_ylabel("Resting Membrane Potential (mV)")
    
    plt.tight_layout()
    plt.show()

# %%
def plot_change_rmp_boxplot_grouped(pivot, use_absolute_change=False):
    """
    Plot change in resting membrane potential (delta RMP) relative to baseline,
    grouped by genotype in a single axis.

    delta RMP is computed per cell as:
        condition - baseline

    Set use_absolute_change=True to plot |delta RMP| (effect size magnitude).
    """
    genotypes = pivot['genotype'].unique()
    conditions = ['Noradrenaline', 'wash']
    colors_bar = ["#EB6F6F", "#89CFF0"]

    plt.figure(figsize=(10, 10))
    ax = plt.gca()

    # Plot style and geometry
    genotype_spacing = 1.5
    condition_width = 0.25
    jitter_amount = 0.08
    np.random.seed(42)

    for g_idx, genotype in enumerate(genotypes):
        group = pivot[pivot['genotype'] == genotype].copy()
        if group.empty:
            continue

        # Compute per-cell changes from baseline
        for cond in conditions:
            group[f'delta_{cond}'] = group[cond] - group['baseline']
            if use_absolute_change:
                group[f'delta_{cond}'] = group[f'delta_{cond}'].abs()

        genotype_center = g_idx * genotype_spacing
        condition_positions = [genotype_center + (i - 0.5) * condition_width for i in range(len(conditions))]

        # Plot individual cells
        for _, row in group.iterrows():
            for i, cond in enumerate(conditions):
                val = row.get(f'delta_{cond}', np.nan)
                if pd.notna(val):
                    x_jittered = condition_positions[i] + np.random.uniform(-jitter_amount, jitter_amount)
                    ax.scatter(
                        x_jittered,
                        val,
                        color=colors_bar[i],
                        alpha=0.65,
                        s=60,
                        zorder=2,
                        edgecolors='black',
                        linewidths=0.1
                    )

        # Plot median lines
        for i, cond in enumerate(conditions):
            vals = group[f'delta_{cond}'].dropna().values
            if len(vals) > 0:
                x_pos = condition_positions[i]
                ax.hlines(np.median(vals), x_pos - 0.1, x_pos + 0.1,
                          color=colors_bar[i], linewidth=4.5, zorder=3)

        # Paired statistical comparison of delta(NA) vs delta(wash)
        paired = group[[f'delta_{conditions[0]}', f'delta_{conditions[1]}']].dropna()
        if len(paired) >= 3:
            try:
                res = pg.ttest(
                    paired[f'delta_{conditions[0]}'],
                    paired[f'delta_{conditions[1]}'],
                    paired=True
                )
                p_val = float(res['p-val'].iloc[0])
                add_significance(ax, [(condition_positions[0], condition_positions[1])], [p_val])
                print(f"{genotype}: delta {conditions[0]} vs delta {conditions[1]} p = {p_val:.4g} (n={len(paired)})")
            except Exception as e:
                print(f"Stats error for {genotype}: {e}")

    # Reference line: no change from baseline
    ax.axhline(0, color='black', linestyle='--', linewidth=1.2, alpha=0.7)

    # Axis formatting
    genotype_centers = [g_idx * genotype_spacing for g_idx in range(len(genotypes))]
    ax.set_xticks(genotype_centers)
    ax.set_xticklabels(['Gad67$^+$', 'Ntsr1$^+$'])

    ylabel = "|Change in RMP| (mV)" if use_absolute_change else "Change in RMP (mV; condition - baseline)"
    ax.set_ylabel(ylabel)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.tight_layout()
    plt.show()


# Example usage:
# Signed change (preserves hyperpolarization/depolarization direction)
plot_change_rmp_boxplot_grouped(pivot)

# Magnitude-only change (effect size):
# plot_change_rmp_boxplot_grouped(pivot, use_absolute_change=True)
# Out:
# Stats error for eGFP-Gad67: 'p-val'
# Stats error for Ai75D/Ntsr1: 'p-val'

# %%
results_excel = "/Users/rbondare/ephys/metadata/all_peak_results_final.xlsx"
results_df = pd.read_excel(results_excel)
print("Columns in results_df:", results_df.columns.tolist())
print(results_df.head())

# Exclude rows where comment is "exclude"
filtered_df = results_df[results_df['comment'].str.strip().str.lower() != "exclude"]
print("number of cells after filtering:", len(filtered_df))

# Create pivot table for RMP data
pivot = filtered_df.pivot_table(
    index=['ID', 'genotype'],
    columns='condition',
    values='RMP'
).reset_index()

print("Pivot table shape:", pivot.shape)
print("Pivot columns:", pivot.columns.tolist())
print(pivot.head())
# Out:
# Columns in results_df: ['filepath', 'filename', 'condition', 'genotype', 'ID', 'total_sweeps', 'normalized_first_peak', 'normalized_all_peaks', 'comment', 'RMP']
#                                             filepath             filename  \
# 0  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...  2025_03_24_0002.abf
# 1  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...  2025_03_24_0003.abf
# 2  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...  2025_03_24_0004.abf
# 3  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...  2025_03_24_0007.abf
# 4  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...  2025_03_24_0008.abf
#
#        condition    genotype  ID  total_sweeps  normalized_first_peak  \
# 0       baseline  eGFP-Gad67   1            18                    1.0
# 1  Noradrenaline  eGFP-Gad67   1            32                    1.0
# 2           wash  eGFP-Gad67   1            42                    1.0
# 3       baseline  eGFP-Gad67   2            25                    1.0
# 4  Noradrenaline  eGFP-Gad67   2            47                    1.0
#
#    normalized_all_peaks comment        RMP
# 0                  1.00     NaN -65.261482
# 1                  1.53     NaN -64.202126
# 2                  1.29     NaN -63.925163
# 3                  1.20     NaN -57.437946
# 4                  1.06     NaN -58.822929
# number of cells after filtering: 81
# Pivot table shape: (27, 6)
# Pivot columns: ['ID', 'genotype', 'Noradrenaline', 'Wash', 'baseline', 'wash']
# condition  ID    genotype  Noradrenaline  Wash   baseline       wash
# 0           1  eGFP-Gad67     -64.202126   NaN -65.261482 -63.925163
# 1           2  eGFP-Gad67     -58.822929   NaN -57.437946 -51.931252
# 2           3  eGFP-Gad67     -67.055130   NaN -67.326889 -67.724258
# 3           5  eGFP-Gad67     -51.996529   NaN -50.071564 -55.767834
# 4           6  eGFP-Gad67     -63.603905   NaN -62.840172 -64.405540

# %%
plot_rmp_boxplot_grouped(pivot)
# Out:
#     Noradrenaline vs baseline: p = 0.0095
#     Noradrenaline vs wash: p = 1.0000
#     baseline vs wash: p = 0.0262
#     Noradrenaline vs baseline: p = 1.0000
#     Noradrenaline vs wash: p = 1.0000
#     baseline vs wash: p = 1.0000

# %%
def plot_rmp_histogram_by_genotype(results_df):
    """
    Plot RMP histograms with separate subplots for each genotype.
    Each subplot shows overlapping histograms for the 3 conditions.
    """
    conditions = ['baseline', 'Noradrenaline', 'wash']
    genotypes = results_df['genotype'].unique()
    
    # Prepare data for histogram
    data_for_plot = []
    for _, row in results_df.iterrows():
        for condition in conditions:
            if pd.notna(row[condition]):
                data_for_plot.append({
                    'condition': condition,
                    'genotype': row['genotype'],
                    'RMP': row[condition]
                })
    
    # Convert to DataFrame
    plot_df = pd.DataFrame(data_for_plot)
    
    if plot_df.empty:
        print("No data to plot")
        return
    
    # Create subplots - one for each genotype
    fig, axes = plt.subplots(1, len(genotypes), figsize=(12, 5), sharey=True)
    
    # Handle case where there's only one genotype
    if len(genotypes) == 1:
        axes = [axes]
    
    # Color palette for conditions
    colors = ['#2E86AB', '#A23B72', '#F18F01']  # Blue, Purple, Orange
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        genotype_data = plot_df[plot_df['genotype'] == genotype]
        
        # Plot histogram for each condition
        for i, condition in enumerate(conditions):
            condition_data = genotype_data[genotype_data['condition'] == condition]['RMP']
            
            if len(condition_data) > 0:
                ax.hist(condition_data, 
                       bins=8, 
                       alpha=0.7, 
                       label=condition,
                       color=colors[i],
                       edgecolor='black',
                       linewidth=0.5)
        
        ax.set_title(f"{genotype}", fontsize=14, fontweight='bold')
        ax.set_xlabel("Resting Membrane Potential (mV)", fontsize=12)
        if idx == 0:  # Only show y-label on leftmost plot
            ax.set_ylabel("Frequency", fontsize=12)
        ax.legend()
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()




def plot_rmp_density(results_df):
    """
    Density plots instead of histograms for smoother visualization
    """
    conditions = ['baseline', 'Noradrenaline']
    genotypes = results_df['genotype'].unique()
    
    # Prepare data
    data_for_plot = []
    for _, row in results_df.iterrows():
        for condition in conditions:
            if pd.notna(row[condition]):
                data_for_plot.append({
                    'condition': condition,
                    'genotype': row['genotype'],
                    'RMP': row[condition]
                })
    
    plot_df = pd.DataFrame(data_for_plot)
    
    if plot_df.empty:
        print("No data to plot")
        return
    
    fig, axes = plt.subplots(1, len(genotypes), figsize=(12, 5), sharey=True)
    
    if len(genotypes) == 1:
        axes = [axes]


    colors = ["#908E8E", "#EB6F6F"] 
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        genotype_data = plot_df[plot_df['genotype'] == genotype]
        
        # Plot density for each condition
        for i, condition in enumerate(conditions):
            condition_data = genotype_data[genotype_data['condition'] == condition]
            
            if len(condition_data) > 0:
                sns.kdeplot(data=condition_data, 
                           x='RMP',
                           label=condition,
                           color=colors[i],
                           fill=True,
                           alpha=0.6,
                           ax=ax)
        
        ax.set_title(f"{genotype}", fontsize=14, fontweight='bold')
        ax.set_xlabel("Resting Membrane Potential (mV)", fontsize=12)
        if idx == 0:
            ax.set_ylabel("Density", fontsize=12)
        ax.legend()
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

plot_rmp_density(pivot)

# %%
def extract_rmp_per_sweep(abf_file):
    """
    Extract resting membrane potential from each individual sweep in an ABF file.
    Returns a list of RMP values, one per sweep.
    """
    try:
        abf = pyabf.ABF(abf_file)
        sweep_rmp_values = []
        
        # Use last 10 sweeps (or all if fewer than 10)
        sweep_indices = abf.sweepList[-10:] if len(abf.sweepList) > 10 else abf.sweepList
        
        for sweep in sweep_indices:
            abf.setSweep(sweep)
            first_100ms = abf.sweepY[:int(0.1 * abf.dataRate)]  # First 100 ms
            sweep_rmp = np.mean(first_100ms)
            sweep_rmp_values.append(sweep_rmp)
        
        return sweep_rmp_values
    
    except Exception as e:
        print(f"Error processing {abf_file}: {e}")
        return []

def create_rmp_per_sweep_dataframe(csv_file_path):
    """
    Create a dataframe with RMP values for each individual sweep.
    """
    # Load the existing results file
    results_df = pd.read_excel(csv_file_path)
    
    # Filter out excluded files
    filtered_df = results_df[results_df['comment'].str.strip().str.lower() != "exclude"]
    
    # Create list to store all sweep data
    all_sweep_data = []
    
    # Process each file
    for i, row in filtered_df.iterrows():
        if pd.notna(row['filepath']) and os.path.exists(row['filepath']):
            print(f"Processing file {i+1}/{len(filtered_df)}: {row['filepath']}")
            
            # Extract RMP from each sweep
            sweep_rmp_values = extract_rmp_per_sweep(row['filepath'])
            
            # Add each sweep as a separate row
            for sweep_idx, rmp_value in enumerate(sweep_rmp_values):
                all_sweep_data.append({
                    'ID': row['ID'],
                    'genotype': row['genotype'],
                    'condition': row['condition'],
                    'sweep_number': sweep_idx + 1,
                    'RMP': rmp_value,
                    'filepath': row['filepath']
                })
        else:
            print(f"File not found: {row.get('filepath', 'N/A')}")
    
    # Convert to DataFrame
    sweep_df = pd.DataFrame(all_sweep_data)
    
    print(f"Created dataframe with {len(sweep_df)} individual sweep measurements")
    print(f"From {len(filtered_df)} cells across {len(sweep_df['genotype'].unique())} genotypes")
    
    return sweep_df

def plot_rmp_histogram_per_sweep(sweep_df):
    """
    Plot RMP histograms using individual sweep data.
    Each subplot shows overlapping histograms for the 3 conditions.
    """
    conditions = ['baseline', 'Noradrenaline']
    genotypes = sweep_df['genotype'].unique()
    
    # Create subplots - one for each genotype
    fig, axes = plt.subplots(1, len(genotypes), figsize=(12, 5), sharey=True)

    # Color palette for conditions
    colors = ["#908E8E", "#EB6F6F"]  
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        genotype_data = sweep_df[sweep_df['genotype'] == genotype]
        
        # Plot histogram for each condition
        for i, condition in enumerate(conditions):
            condition_data = genotype_data[genotype_data['condition'] == condition]['RMP']
            
            if len(condition_data) > 0:
                ax.hist(condition_data, 
                       bins=15,  # More bins since we have more data points
                       alpha=0.7, 
                       label=f"{condition} (n={len(condition_data)})",
                       color=colors[i],
                       edgecolor='black',
                       linewidth=0.5)
        
        ax.set_title(f"{genotype}", fontsize=14, fontweight='bold')
        ax.set_xlabel("Resting Membrane Potential (mV)", fontsize=12)
        if idx == 0:  # Only show y-label on leftmost plot
            ax.set_ylabel("Frequency (Individual Sweeps)", fontsize=12)
        ax.legend()
        ax.grid(True, alpha=0.3)
    
    plt.suptitle("RMP Distribution - Individual Sweep Data", fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()

def plot_rmp_density_per_sweep(sweep_df):
    """
    Density plots using individual sweep data for smoother visualization
    """
    conditions = ['baseline', 'Noradrenaline']
    genotypes = sweep_df['genotype'].unique()
    
    fig, axes = plt.subplots(1, len(genotypes), figsize=(12, 5), sharey=True)
    
    if len(genotypes) == 1:
        axes = [axes]
    
    colors = ["#908E8E", "#EB6F6F"] 
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        genotype_data = sweep_df[sweep_df['genotype'] == genotype]
        
        # Plot density for each condition
        for i, condition in enumerate(conditions):
            condition_data = genotype_data[genotype_data['condition'] == condition]
            
            if len(condition_data) > 0:
                sns.kdeplot(data=condition_data, 
                           x='RMP',
                           label=f"{condition} (n={len(condition_data)})",
                           color=colors[i],
                           fill=True,
                           alpha=0.6,
                           ax=ax)
        
        ax.set_title(f"{genotype}", fontsize=14, fontweight='bold')
        ax.set_xlabel("Resting Membrane Potential (mV)", fontsize=12)
        if idx == 0:
            ax.set_ylabel("Density", fontsize=12)
        ax.legend()
        ax.grid(True, alpha=0.3)
    
    plt.suptitle("RMP Distribution - Individual Sweep Data (Density)", fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()

# Usage example:
results_csv = "C:\\Users\\rbondare\\ephys\\results\\all_peak_results_final.xlsx"

# Create dataframe with individual sweep data
sweep_df = create_rmp_per_sweep_dataframe(results_excel)

# Display some info about the data
print("\nDataframe info:")
print(sweep_df.head())
print(f"\nData summary:")
print(sweep_df.groupby(['genotype', 'condition']).agg({
    'RMP': ['count', 'mean', 'std'],
    'ID': 'nunique'
}).round(2))

# Plot histograms
plot_rmp_histogram_per_sweep(sweep_df)

# Plot density plots
plot_rmp_density_per_sweep(sweep_df)
# Out:
# Processing file 1/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0002.abf
# Processing file 2/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0003.abf
# Processing file 3/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0004.abf
# Processing file 4/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0007.abf
# Processing file 5/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0008.abf
# Processing file 6/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0009.abf
# Processing file 7/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0012.abf
# Processing file 8/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0013.abf
# Processing file 9/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/24.03.2025 M1/2025_03_24_0014.abf
# Processing file 13/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0012.abf
# Processing file 14/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0013.abf
# Processing file 15/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0014.abf
# Processing file 16/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0018.abf
# Processing file 17/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0019.abf
# Processing file 18/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M2/2025_03_25_0020.abf
# Processing file 19/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0025.abf
# Processing file 20/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0026.abf
# Processing file 21/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0027.abf
# Processing file 22/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0031.abf
# Processing file 23/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0032.abf
# Processing file 24/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0033.abf
# Processing file 25/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0039.abf
# Processing file 26/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0040.abf
# Processing file 27/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/25.03.2025 M3/2025_03_25_0041.abf
# Processing file 28/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0020.abf
# Processing file 29/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0021.abf
# Processing file 30/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0022.abf
# Processing file 34/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0031.abf
# Processing file 35/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0032.abf
# Processing file 36/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/26.03.2025 M5/2025_03_26_0033.abf
# Processing file 37/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0002.abf
# Processing file 38/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0003.abf
# Processing file 39/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0004.abf
# Processing file 40/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0007.abf
# Processing file 41/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0008.abf
# Processing file 42/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0009.abf
# Processing file 43/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0012.abf
# Processing file 44/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0013.abf
# Processing file 45/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/29.03.2025 M6/2025_03_29_0014.abf
# Processing file 46/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/13.05.2025 M7/2025_05_13_0031.abf
# Processing file 47/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/13.05.2025 M7/2025_05_13_0032.abf
# Processing file 48/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/13.05.2025 M7/2025_05_13_0033.abf
# Processing file 49/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M8/2025_05_15_0002.abf
# Processing file 50/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M8/2025_05_15_0003.abf
# Processing file 51/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M8/2025_05_15_0004.abf
# Processing file 52/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0026.abf
# Processing file 53/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0027.abf
# Processing file 54/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0028.abf
# Processing file 55/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0033.abf
# Processing file 56/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0034.abf
# Processing file 57/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/gad/15.05.2025 M9/2025_05_15_0035.abf
# Processing file 58/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0001.abf
# Processing file 59/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0002.abf
# Processing file 60/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0003.abf
# Processing file 61/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0006.abf
# Processing file 62/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0007.abf
# Processing file 63/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0008.abf
# Processing file 64/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0011.abf
# Processing file 65/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0012.abf
# Processing file 66/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M4/2025_05_12_0013.abf
# Processing file 67/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0017.abf
# Processing file 68/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0018.abf
# Processing file 69/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0019.abf
# Processing file 70/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0022.abf
# Processing file 71/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0023.abf
# Processing file 72/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0024.abf
# Processing file 73/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0028.abf
# Processing file 74/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0029.abf
# Processing file 75/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/12.05.2025 M5/2025_05_12_0030.abf
# Processing file 76/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0002.abf
# Processing file 77/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0003.abf
# Processing file 78/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0004.abf
# Processing file 79/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0008.abf
# Processing file 80/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0009.abf
# Processing file 81/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0010.abf
# Processing file 82/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0014.abf
# Processing file 84/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/13.05.2025 M6/2025_05_13_0016.abf
# Processing file 86/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0018.abf
# Processing file 87/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0015.abf
# Processing file 88/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0016.abf
# Processing file 90/81: /Volumes/joeschgrp/Group Members/Rima/Ephys_NE/DATA/ntsr1/19.02.2025 M1/2025_02_19_0018.abf
# Created dataframe with 807 individual sweep measurements
# From 81 cells across 2 genotypes
#
# Dataframe info:
#    ID    genotype condition  sweep_number        RMP  \
# 0   1  eGFP-Gad67  baseline             1 -64.013748
# 1   1  eGFP-Gad67  baseline             2 -64.737183
# 2   1  eGFP-Gad67  baseline             3 -64.742020
# 3   1  eGFP-Gad67  baseline             4 -64.224792
# 4   1  eGFP-Gad67  baseline             5 -65.768440
#
#                                             filepath
# 0  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...
# 1  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...
# 2  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...
# 3  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...
# 4  /Volumes/joeschgrp/Group Members/Rima/Ephys_NE...
#
# Data summary:
#                             RMP                       ID
#                           count       mean   std nunique
# genotype    condition
# Ai75D/Ntsr1 Noradrenaline    97 -56.610001  3.83      10
#             Wash             10 -50.740002  0.42       1
#             baseline        100 -54.799999  3.86      10
#             wash             90 -55.810001  4.39       9
# eGFP-Gad67  Noradrenaline   170 -58.070000  7.27      17
#             baseline        170 -62.590000  6.00      17
#             wash            170 -58.860001  6.88      17

# %%
# Plot histogram of membrane potential change using individual sweep data
from scipy import stats

def plot_delta_rmp_per_sweep_histogram(sweep_df):
    """
    Plot histogram of membrane potential change (Noradrenaline - baseline) 
    using individual sweep data for each genotype, with centered x-axes.
    Uses the same sweep extraction basis as the existing functions.
    """
    genotypes = sweep_df['genotype'].unique()
    conditions = ['baseline', 'Noradrenaline']
    
    # First, calculate all delta values to determine common x-axis range
    all_deltas = []
    genotype_deltas = {}
    
    for genotype in genotypes:
        genotype_data = sweep_df[sweep_df['genotype'] == genotype]
        cell_deltas = []
        
        # For each cell, calculate delta for each sweep
        for cell_id in genotype_data['ID'].unique():
            cell_data = genotype_data[genotype_data['ID'] == cell_id]
            
            baseline_sweeps = cell_data[cell_data['condition'] == 'baseline']['RMP'].values
            na_sweeps = cell_data[cell_data['condition'] == 'Noradrenaline']['RMP'].values
            
            # Calculate mean baseline and mean NA for this cell, then delta
            if len(baseline_sweeps) > 0 and len(na_sweeps) > 0:
                baseline_mean = np.mean(baseline_sweeps)
                # For each NA sweep, calculate delta from baseline mean
                for na_val in na_sweeps:
                    delta = na_val - baseline_mean
                    cell_deltas.append(delta)
        
        genotype_deltas[genotype] = cell_deltas
        all_deltas.extend(cell_deltas)
    
    # Determine common x-axis range for centering
    if all_deltas:
        x_min = min(all_deltas) - 1
        x_max = max(all_deltas) + 1
        bins = np.linspace(x_min, x_max, 15)
    else:
        print("No data to plot")
        return
    
    # Create subplots - one for each genotype
    fig, axes = plt.subplots(1, len(genotypes), figsize=(12, 5), sharey=True)
    
    if len(genotypes) == 1:
        axes = [axes]
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        delta_data = genotype_deltas[genotype]
        
        if len(delta_data) > 0:
            # Plot histogram
            ax.hist(delta_data, bins=bins, color="#707070", edgecolor='black', 
                   alpha=0.7, density=False)
            
            # Add vertical line at zero (centered)
            ax.axvline(0, color='black', linestyle='--', linewidth=2, alpha=0.8)
            
            # Add sample size to plot
            ax.text(0.02, 0.98, f'n = {len(delta_data)} sweeps', 
                   transform=ax.transAxes, fontsize=11, 
                   verticalalignment='top', 
                   bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
        
            
            ax.set_title(f"{genotype}", fontsize=14, fontweight='bold')
            ax.set_xlabel("Membrane Potential Change (mV)", fontsize=12, fontweight='bold')
            ax.legend()
            # ax.grid(True, alpha=0.3)
            
            # Set same x-axis range for all plots (centered)
            ax.set_xlim(x_min, x_max)
            
    # Set y-label only on leftmost plot
    axes[0].set_ylabel("Number of Sweeps", fontsize=12, fontweight='bold')
    
    plt.suptitle("Membrane Potential Change (NA - Baseline)\nIndividual Sweep Data", 
                 fontsize=16)
    plt.tight_layout()
    plt.show()

plot_delta_rmp_per_sweep_histogram(sweep_df)
# Out:
# /var/folders/pj/c6v4sq5n3pn_r1qk76bj_z3c0000gn/T/ipykernel_96945/1626754783.py:75: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
from scipy import stats

def plot_delta_rmp_per_sweep_histogram_single(sweep_df):
    """
    Plot histogram of membrane potential change (Noradrenaline - baseline) 
    using individual sweep data in a single figure with different patterns for each genotype.
    Uses the same sweep extraction basis as the existing functions.
    """
    genotypes = sweep_df['genotype'].unique()
    conditions = ['baseline', 'Noradrenaline']
    
    # First, calculate all delta values to determine common x-axis range
    all_deltas = []
    genotype_deltas = {}
    
    for genotype in genotypes:
        genotype_data = sweep_df[sweep_df['genotype'] == genotype]
        cell_deltas = []
        
        # For each cell, calculate delta for each sweep
        for cell_id in genotype_data['ID'].unique():
            cell_data = genotype_data[genotype_data['ID'] == cell_id]
            
            baseline_sweeps = cell_data[cell_data['condition'] == 'baseline']['RMP'].values
            na_sweeps = cell_data[cell_data['condition'] == 'Noradrenaline']['RMP'].values
            
            # Calculate mean baseline and mean NA for this cell, then delta
            if len(baseline_sweeps) > 0 and len(na_sweeps) > 0:
                baseline_mean = np.mean(baseline_sweeps)
                # For each NA sweep, calculate delta from baseline mean
                for na_val in na_sweeps:
                    delta = na_val - baseline_mean
                    cell_deltas.append(delta)
        
        genotype_deltas[genotype] = cell_deltas
        all_deltas.extend(cell_deltas)
    
    # Determine common x-axis range for centering
    if all_deltas:
        x_min = min(all_deltas) - 1
        x_max = max(all_deltas) + 1
        bins = np.linspace(x_min, x_max, 35)
    else:
        print("No data to plot")
        return
    
    # Create single figure
    plt.figure(figsize=( 10, 10))
   
    
    # Define patterns and colors for each genotype
    patterns = {
        'Ai75D\\Ntsr1': None,   # Striped pattern for GAD67
        'eGFP-Gad67': '//'  # No fill (empty) for NTSR1
    }
    # Use transparent fill for histogram bars
    colors = {
        'Ai75D\\Ntsr1':  'gray',
        'eGFP-Gad67': 'white'  
    }
    
    edge_colors = {
        'Ai75D\\Ntsr1': 'black',
        'eGFP-Gad67': 'black'
    }
    
    alphas = {
        'Ai75D\\Ntsr1': 0.6,
        'eGFP-Gad67': 0.8  
    }
    
    
    # Plot histograms for each genotype
    for genotype in genotypes:
        delta_data = genotype_deltas[genotype]
        
        if len(delta_data) > 0:
            plt.hist(delta_data, 
                    bins=bins, 
                    label=f'{genotype} (n={len(delta_data)} sweeps)',
                    color=colors.get(genotype, "#848383"),
                    edgecolor=edge_colors.get(genotype, 'black'),
                    hatch=patterns.get(genotype, None),
                    alpha=alphas.get(genotype, 0.7),
                    linewidth=2)
    
    # Add vertical line at zero (centered)
    plt.axvline(0, color='black', linestyle='--', linewidth=2, alpha=0.8)
    
    # Formatting
    plt.xlabel("Membrane Potential Change (mV)")
    plt.ylabel("Number of Sweeps")
    #plt.title("Membrane Potential Change (NA - Baseline)\nIndividual Sweep Data")
    # Custom legend labels
    handles, labels = plt.gca().get_legend_handles_labels()
    custom_labels = []
    for label in labels:
        if 'Ai75D\\Ntsr1' in label:
            custom_labels.append(label.replace('Ai75D\\Ntsr1', 'Ntsr1+'))
        elif 'eGFP-Gad67' in label:
            custom_labels.append(label.replace('eGFP-Gad67', 'Gad67+'))
        else:
            custom_labels.append(label)

    plt.legend(custom_labels, fontsize=18)
    plt.xlim(x_min, x_max)
    
    # Remove top and right spines
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    plt.tight_layout()
    plt.savefig("rmp_change_histogram.pdf", dpi=300)
    plt.show()

# Usage with your sweep_df
plot_delta_rmp_per_sweep_histogram_single(sweep_df)

# %%
from scipy import stats

def plot_delta_rmp_bar_from_sweeps(sweep_df):
    """
    Plot NA-baseline change as a bar plot using one value per cell.
    This avoids pseudo-replication from treating each sweep as independent.
    """
    required = {'ID', 'genotype', 'condition', 'RMP'}
    missing = required - set(sweep_df.columns)
    if missing:
        raise KeyError(f"sweep_df is missing required columns: {missing}")

    # 1) Collapse sweeps to one mean RMP per cell per condition
    cell_means = (
        sweep_df
        .groupby(['ID', 'genotype', 'condition'], as_index=False)['RMP']
        .mean()
    )

    # 2) Compute one delta per cell
    wide = (
        cell_means
        .pivot_table(index=['ID', 'genotype'], columns='condition', values='RMP')
        .reset_index()
    )

    if 'baseline' not in wide.columns or 'Noradrenaline' not in wide.columns:
        raise KeyError("Need both 'baseline' and 'Noradrenaline' conditions in sweep_df")

    wide['delta_NA'] = wide['Noradrenaline'] - wide['baseline']
    delta_df = wide.dropna(subset=['delta_NA']).copy()

    if delta_df.empty:
        print('No paired baseline/NA cell data found.')
        return delta_df

    genotypes = list(delta_df['genotype'].unique())
    x = np.arange(len(genotypes), dtype=float)

    fig, ax = plt.subplots(figsize=(7, 6))

    means = []
    sems = []
    grouped_values = []

    for genotype in genotypes:
        vals = delta_df.loc[delta_df['genotype'] == genotype, 'delta_NA'].values
        grouped_values.append(vals)
        means.append(np.mean(vals))
        sems.append(np.std(vals, ddof=1) / np.sqrt(len(vals)) if len(vals) > 1 else 0)

    # Bars + error bars
    ax.bar(x, means, width=0.6, color='#8FB3C9', edgecolor='black', alpha=0.55, zorder=1)
    ax.errorbar(x, means, yerr=sems, fmt='none', ecolor='black', capsize=4, linewidth=1.4, zorder=3)

    # Cell-level points
    np.random.seed(42)
    for i, vals in enumerate(grouped_values):
        jitter = np.random.uniform(-0.09, 0.09, size=len(vals))
        ax.scatter(np.full(len(vals), x[i]) + jitter, vals, s=42, color='#2F5D7C',
                   edgecolor='black', linewidth=0.3, alpha=0.85, zorder=4)

    # One-sample test vs zero per genotype (does NA shift from baseline?)
    y_all = np.concatenate(grouped_values)
    y_span = max(1.0, float(np.nanmax(y_all) - np.nanmin(y_all)))
    top_base = float(np.nanmax(np.r_[means, y_all]))

    for i, vals in enumerate(grouped_values):
        if len(vals) >= 3:
            p = stats.ttest_1samp(vals, 0, nan_policy='omit').pvalue
            if p < 0.001:
                star = '***'
            elif p < 0.01:
                star = '**'
            elif p < 0.05:
                star = '*'
            else:
                star = 'n.s.'
            ax.text(x[i], means[i] + sems[i] + 0.08 * y_span, star,
                    ha='center', va='bottom', fontsize=12)
            print(f"{genotypes[i]} vs 0: p={p:.4g} (n={len(vals)})")

    # Between-genotype comparison on per-cell deltas (Welch t-test)
    if len(grouped_values) == 2 and len(grouped_values[0]) >= 3 and len(grouped_values[1]) >= 3:
        p_between = stats.ttest_ind(grouped_values[0], grouped_values[1], equal_var=False, nan_policy='omit').pvalue
        y = top_base + 0.22 * y_span
        h = 0.05 * y_span
        ax.plot([x[0], x[0], x[1], x[1]], [y, y + h, y + h, y], color='black', linewidth=1.4)
        if p_between < 0.001:
            label = '***'
        elif p_between < 0.01:
            label = '**'
        elif p_between < 0.05:
            label = '*'
        else:
            label = 'n.s.'
        ax.text(np.mean([x[0], x[1]]), y + h * 1.05, label, ha='center', va='bottom', fontsize=12)
        print(f"Between-genotype delta comparison: p={p_between:.4g}")

    # Formatting
    pretty = []
    for g in genotypes:
        if g == 'eGFP-Gad67':
            pretty.append('Gad67$^+$')
        elif g == 'Ai75D/Ntsr1':
            pretty.append('Ntsr1$^+$')
        else:
            pretty.append(g)

    ax.axhline(0, linestyle='--', linewidth=1.1, color='black', alpha=0.7)
    ax.set_xticks(x)
    ax.set_xticklabels(pretty)
    ax.set_ylabel('Delta RMP (NA - baseline, mV)')
    ax.set_title('Cell-level change from sweep data')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(axis='y', alpha=0.2)

    plt.tight_layout()
    plt.show()

    return delta_df

# Run this on your current sweep dataframe
delta_cell_df = plot_delta_rmp_bar_from_sweeps(sweep_df)
# Out:
# eGFP-Gad67 vs 0: p=0.003174 (n=17)
# Ai75D/Ntsr1 vs 0: p=0.2412 (n=10)
# Between-genotype delta comparison: p=0.003979

# %%
# Plot histogram of membrane potential change using cell averages
from scipy import stats

def plot_delta_rmp_cell_averages(results_csv):
    """
    Plot histogram of membrane potential change (Noradrenaline - baseline) 
    using cell averages for each genotype, with centered x-axes.
    """
    # Load and filter data
    results_df = pd.read_excel(results_csv)
    filtered_df = results_df[results_df['comment'].str.strip().str.lower() != "exclude"]
    
    # Create pivot table for RMP data (same as your existing pivot)
    pivot = filtered_df.pivot_table(
        index=['ID', 'genotype'],
        columns='condition',
        values='RMP'
    ).reset_index()
    
    genotypes = pivot['genotype'].unique()
    
    # Calculate delta values for each genotype
    all_deltas = []
    genotype_deltas = {}
    
    for genotype in genotypes:
        # Select rows for this genotype where both baseline and Noradrenaline are not NaN
        df_sub = pivot[(pivot['genotype'] == genotype) & 
                       pivot['baseline'].notna() & 
                       pivot['Noradrenaline'].notna()]
        
        # Calculate delta RMP (Noradrenaline - baseline) for each cell
        delta_rmp = df_sub['Noradrenaline'] - df_sub['baseline']
        
        genotype_deltas[genotype] = delta_rmp.values
        all_deltas.extend(delta_rmp.values)
    
    # Determine common x-axis range for centering
    if all_deltas:
        x_min = min(all_deltas) - 1
        x_max = max(all_deltas) + 1
        bins = np.linspace(x_min, x_max, 5)
    else:
        print("No data to plot")
        return
    
    # Create subplots - one for each genotype
    fig, axes = plt.subplots(1, len(genotypes), figsize=(12, 5), sharey=True)
    
    if len(genotypes) == 1:
        axes = [axes]
    
    for idx, genotype in enumerate(genotypes):
        ax = axes[idx]
        delta_data = genotype_deltas[genotype]
        
        if len(delta_data) > 0:
            # Plot histogram
            ax.hist(delta_data, bins=bins, color='#2E86AB', edgecolor='black', 
                   alpha=0.7, density=False)
        
            # Add vertical line at zero
            ax.axvline(0, color='gray', linestyle='--', linewidth=2, alpha=0.8)

            
            # Add sample size to plot
            ax.text(0.02, 0.98, f'n = {len(delta_data)} cells', 
                   transform=ax.transAxes, fontsize=11, 
                   verticalalignment='top', 
                   bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
            
            # Perform t-test against zero
            t_stat, p_val = stats.ttest_1samp(delta_data, 0)
            ax.text(0.02, 0.88, f'p = {p_val:.4f}', 
                   transform=ax.transAxes, fontsize=11, 
                   verticalalignment='top', 
                   bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
            
            ax.set_title(f"{genotype}", fontsize=14, fontweight='bold')
            ax.set_xlabel("Noradrenaline - Baseline (mV)", fontsize=12, fontweight='bold')
            ax.legend()
            
            # Set same x-axis range for all plots (centered)
            ax.set_xlim(x_min, x_max)
            
    # Set y-label only on leftmost plot
    axes[0].set_ylabel("Number of Cells", fontsize=12, fontweight='bold')
    
    plt.suptitle("Membrane Potential Change (NA - Baseline)\nCell Averages", 
                 fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()

# Run the function
results_csv = "C:\\Users\\rbondare\\ephys\\results\\all_peak_results_final.xlsx"
plot_delta_rmp_cell_averages(results_excel)
# Out:
# /var/folders/pj/c6v4sq5n3pn_r1qk76bj_z3c0000gn/T/ipykernel_96945/4155404497.py:81: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
